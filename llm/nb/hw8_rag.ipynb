# %% [markdown]
# Цель данного домашнего задания — познакомить вас с концепцией и реализацией RAG в LLM, а также развить навыки интеграции механизмов поиска с языковыми моделями. Вы научитесь извлекать данные из специализированных источников, использовать их для поддержки генеративного процесса и оценивать качество полученных результатов.

# %% [markdown]
# # Устанавливаем зависимости

# %%
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to c:\users\adm\appdata\local\temp\pip-req-build-q44i1pf8
#   Resolved https://github.com/huggingface/transformers.git to commit 6b550462139655d488d4c663086a63e98713c6b9
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: filelock in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers==4.49.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\my\deepschool-llm\venv\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.49.0.dev0) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\my\deepschool-llm\venv\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.49.0.dev0) (4.12.2)
# Requirement already satisfied: colorama in d:\my\deepschool-llm\venv\lib\site-packages (from tqdm>=4.27->transformers==4.49.0.dev0) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\my\deepschool-llm\venv\lib\site-packages (from requests->transformers==4.49.0.dev0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\my\deepschool-llm\venv\lib\site-packages (from requests->transformers==4.49.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\my\deepschool-llm\venv\lib\site-packages (from requests->transformers==4.49.0.dev0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\my\deepschool-llm\venv\lib\site-packages (from requests->transformers==4.49.0.dev0) (2024.12.14)
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git 'C:\Users\adm\AppData\Local\Temp\pip-req-build-q44i1pf8'

# %%
# !pip install datasets sentence_transformers trl
# Out:
# Requirement already satisfied: datasets in d:\my\deepschool-llm\venv\lib\site-packages (3.2.0)
# Requirement already satisfied: sentence_transformers in d:\my\deepschool-llm\venv\lib\site-packages (3.4.1)
# Requirement already satisfied: trl in d:\my\deepschool-llm\venv\lib\site-packages (0.14.0)
# Requirement already satisfied: filelock in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in d:\my\deepschool-llm\venv\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\my\deepschool-llm\venv\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in d:\my\deepschool-llm\venv\lib\site-packages (from sentence_transformers) (4.49.0.dev0)
# Requirement already satisfied: torch>=1.11.0 in d:\my\deepschool-llm\venv\lib\site-packages (from sentence_transformers) (2.5.1+cu124)
# Requirement already satisfied: scikit-learn in d:\my\deepschool-llm\venv\lib\site-packages (from sentence_transformers) (1.6.0)
# Requirement already satisfied: scipy in d:\my\deepschool-llm\venv\lib\site-packages (from sentence_transformers) (1.14.1)
# Requirement already satisfied: Pillow in d:\my\deepschool-llm\venv\lib\site-packages (from sentence_transformers) (10.4.0)
# Requirement already satisfied: accelerate>=0.34.0 in d:\my\deepschool-llm\venv\lib\site-packages (from trl) (1.2.1)
# Requirement already satisfied: rich in d:\my\deepschool-llm\venv\lib\site-packages (from trl) (13.9.4)
# Requirement already satisfied: psutil in d:\my\deepschool-llm\venv\lib\site-packages (from accelerate>=0.34.0->trl) (6.1.1)
# Requirement already satisfied: safetensors>=0.4.3 in d:\my\deepschool-llm\venv\lib\site-packages (from accelerate>=0.34.0->trl) (0.4.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\my\deepschool-llm\venv\lib\site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\my\deepschool-llm\venv\lib\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\my\deepschool-llm\venv\lib\site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\my\deepschool-llm\venv\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\my\deepschool-llm\venv\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\my\deepschool-llm\venv\lib\site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\my\deepschool-llm\venv\lib\site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\my\deepschool-llm\venv\lib\site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\my\deepschool-llm\venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\my\deepschool-llm\venv\lib\site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\my\deepschool-llm\venv\lib\site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\my\deepschool-llm\venv\lib\site-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: networkx in d:\my\deepschool-llm\venv\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in d:\my\deepschool-llm\venv\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.5)
# Requirement already satisfied: setuptools in d:\my\deepschool-llm\venv\lib\site-packages (from torch>=1.11.0->sentence_transformers) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in d:\my\deepschool-llm\venv\lib\site-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\my\deepschool-llm\venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: colorama in d:\my\deepschool-llm\venv\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\my\deepschool-llm\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\my\deepschool-llm\venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\my\deepschool-llm\venv\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\my\deepschool-llm\venv\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\my\deepschool-llm\venv\lib\site-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\my\deepschool-llm\venv\lib\site-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\my\deepschool-llm\venv\lib\site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\my\deepschool-llm\venv\lib\site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: mdurl~=0.1 in d:\my\deepschool-llm\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in d:\my\deepschool-llm\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\my\deepschool-llm\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)

# %% [markdown]
# # Текст на чанки - 5 баллов

# %% [markdown]
# Для наших заданий будем использовать датасет rag-dataset-12000, в котором есть вопросы, ответы и большие контексты.

# %%
from datasets import load_dataset
wikiq = load_dataset('neural-bridge/rag-dataset-12000')

print(len(wikiq['train']))
print(wikiq['train'][0]['question'], '\n')
print(wikiq['train'][0]['answer'], '\n')
print(wikiq['train'][0]['context'], '\n')
# Out:
# 9600
# What is the Berry Export Summary 2028 and what is its purpose?
#
# The Berry Export Summary 2028 is a dedicated export plan for the Australian strawberry, raspberry, and blackberry industries. It maps the sectors’ current position, where they want to be, high-opportunity markets, and next steps. The purpose of this plan is to grow their global presence over the next 10 years.
#
# Caption: Tasmanian berry grower Nic Hansen showing Macau chef Antimo Merone around his property as part of export engagement activities.
# THE RISE and rise of the Australian strawberry, raspberry and blackberry industries has seen the sectors redouble their international trade focus, with the release of a dedicated export plan to grow their global presence over the next 10 years.
# Driven by significant grower input, the Berry Export Summary 2028 maps the sectors’ current position, where they want to be, high-opportunity markets and next steps.
# Hort Innovation trade manager Jenny Van de Meeberg said the value and volume of raspberry and blackberry exports rose by 100 per cent between 2016 and 2017. She said the Australian strawberry industry experienced similar success with an almost 30 per cent rise in export volume and a 26 per cent rise in value to $32.6M over the same period.
# “Australian berry sectors are in a firm position at the moment,” she said. “Production, adoption of protected substrate cropping, improved genetics and an expanding geographic footprint have all helped put Aussie berries on a positive trajectory.
# “We are seeing a real transition point. Broad industry interest and a strong commercial appetite for export market development combined with the potential to capitalise on existing trade agreements and build new trade partnerships has created this perfect environment for growth.”
# High-income countries across Europe, North America and Northern Asia have been identified as having a palate for Australian grown berries with more than 4244 tonnes of fresh berries exported in the last financial year alone.
# The strategy identified the best short-term prospect markets for the Australian blackberry and raspberry industry as Hong Kong, Singapore, The United Arab Emirates and Canada. The strongest short-term trade options identified for the strawberry sector were Thailand, Malaysia, New Zealand and Macau.
# The strategy focuses heavily on growing the existing strawberry export market from 4 per cent to at least 8 per cent of national production by volume, in markets with a capacity and willingness to pay a premium for quality fruit. For raspberries and blackberries, the sectors aim to achieve a 5 per cent boost in exports assessed by volume across identified markets by 2021.
# Tasmanian raspberry exporter Nic Hansen said Australia offers some of the sweetest and most attractive berries in the world, and this combined with our stringent food safety standards across all stages of the supply chain puts growers in a solid position.
# “We have a great product, we are hungry to expand trade and now with this new plan in place, we have a clear roadmap towards driving growth,” Mr Hansen said.
# He said it is exciting to see new export market prospects for raspberries: “The more options we have for export the better. Now we just have to get on with the job of ensuring industry has all the tools it needs, such as supporting data and relationship building opportunities, to thrive in new markets.”
# This project was commissioned by Hort Innovation, and developed by market analysts and research consultants Auspex Strategic Advisory and AgInfinity. Hort Innovation will work now with berry sectors to determine levy-funded activities to support trade.
# See a summary of the strategy on the Hort Innovation website.
# For more information on the berry industries, refer to the Horticulture Statistics Handbook and the Strategic Investment Plans for strawberries, raspberries and blackberries. Growers seeking more information should email trade@horticulture.com.au

# %% [markdown]
# Для налаживания процессов возьме 100 самых длинных текстов

# %%
k_longest = 100
train_data = sorted(wikiq['train'], key=lambda w: len(w["context"]))[-k_longest:]

train_full_docs = [elem['context'] for elem in train_data]
train_queries = [elem['question'] for elem in train_data]

# %% [markdown]
# Реализуйте класс Chunker, в котором метод split_text_to_chunks разбивает входный текст на чанки с перекрытием и возвращает список полученных чанков, и метод get_chunked_list, которые по списку текстов возвращает список чанков из этих текстов согласно методу split_text_to_chunks. Размер чанка и перекрытие измеряется в кол-ве слов, то есть chunk_words = 10 означает, что чанк состоит из 10 слов (слова - сущности, которые получаются после простого сплита строки по одному пробелу " "), перекрытие 3 означает, что если взять два соседний чанка, то 3 последних слова первого являются 3мя первыми словами второго чанка.

# %%
class Chunker:
    def __init__(self, chunk_words: int = 100, overlap: int = 30):
        assert chunk_words > 0 and overlap < chunk_words, "Overlap should be less than chunk_words"
        self.chunk_words = chunk_words
        self.overlap = overlap

    def split_text_to_chunks(self, text: str) -> list[str]:
        chunks = []
        words = text.split()

        while words:
            chunk = " ".join(words[:self.chunk_words])
            chunks.append(chunk)
            words = words[self.chunk_words - self.overlap:]

        return chunks

    def get_chunked_list(self, texts: list[str]) -> list[str]:
        chunks = []
        for text in texts:
            chunks.extend(self.split_text_to_chunks(text))
        return chunks

# %%
chunker = Chunker(chunk_words=100, overlap=30)
train_chunked_docs = chunker.get_chunked_list(train_full_docs)
print(train_chunked_docs, '\n')
print(train_chunked_docs[0], '\n')
print(train_chunked_docs[1])
# Out:
# ['The path to caregiver can be long and slow as one watches a friend or loved one slowly show signs of decline. It can also be quick and unexpected, brought on by sudden illness or accident. Slow or quick, this is the most difficult and often turbulent time for everyone involved. The first hurdle is recognizing and/or admitting that your loved one needs help. At the same time it is most difficult for the patient to admit the need for help. There can be a tremendous amount of denial as we begin to see the signs. At first this is', 'most difficult for the patient to admit the need for help. There can be a tremendous amount of denial as we begin to see the signs. At first this is usually facilitated by the loved one\'s struggle to hide changes in ability. Vanity, pride, and stubbornness are very strong motivators and during this period they may intensify. The patient can be very clever at hiding difficulties. Often the future caregiver is only too eager to believe that everything is fine. "The first step toward change is awareness. The second step is acceptance." nathaniel branden I went through this struggle for', 'is only too eager to believe that everything is fine. "The first step toward change is awareness. The second step is acceptance." nathaniel branden I went through this struggle for the first time with my own mother. I was young. My mother was good at hiding what was happening to her until the decline was too great to hide. Some bills went unpaid while others were paid more than once. She stacked piles of mail with the intention of "looking at it later". She began neglecting her personal hygiene. These things were completely out of character for the proud, strong', 'She stacked piles of mail with the intention of "looking at it later". She began neglecting her personal hygiene. These things were completely out of character for the proud, strong and proper woman she had always been. It took a couple of serious falls and injuries for me to realize that something had to be done. I assumed the household and financial responsibilities. With the help of my sister, we tended to my mother\'s personal chores. None of this was easy. There were so many emotional issues involved. I was embarrassed. I was sad. I was nearly overwhelmed. I learned', "tended to my mother's personal chores. None of this was easy. There were so many emotional issues involved. I was embarrassed. I was sad. I was nearly overwhelmed. I learned and grew. I found a home health aide to come in a few days a week and this made all the difference. It is around this topic that I have gotten the most questions from friends and acquaintances. One of the most common themes is that a loved one is failing but refusing help. For a short time while she was in this transition period one of my friends would", "the most common themes is that a loved one is failing but refusing help. For a short time while she was in this transition period one of my friends would call me, exasperated that her mother was refusing help. The mother was living on her own and belligerently independent. Medicine wasn't being taken appropriately. She fell out of bed. Meals were being missed. My friend was worried and frightened but struggling with crossing the threshold from daughter to caregiver. My advice was that we need to decide when to override a loved one's desire for independence for the sake of", 'struggling with crossing the threshold from daughter to caregiver. My advice was that we need to decide when to override a loved one\'s desire for independence for the sake of safety. I remember saying: "you wouldn\'t leave your kids at home without a babysitter just because they didn\'t want one". There is a fine line between independence and neglect. We all walk that line and learn as we go. Some of us make better decisions than others. That friend of mine made all the right decisions. She took charge. She faced reality. She hired help. I have see others who', "of us make better decisions than ...
#
# The path to caregiver can be long and slow as one watches a friend or loved one slowly show signs of decline. It can also be quick and unexpected, brought on by sudden illness or accident. Slow or quick, this is the most difficult and often turbulent time for everyone involved. The first hurdle is recognizing and/or admitting that your loved one needs help. At the same time it is most difficult for the patient to admit the need for help. There can be a tremendous amount of denial as we begin to see the signs. At first this is
#
# most difficult for the patient to admit the need for help. There can be a tremendous amount of denial as we begin to see the signs. At first this is usually facilitated by the loved one's struggle to hide changes in ability. Vanity, pride, and stubbornness are very strong motivators and during this period they may intensify. The patient can be very clever at hiding difficulties. Often the future caregiver is only too eager to believe that everything is fine. "The first step toward change is awareness. The second step is acceptance." nathaniel branden I went through this struggle for

# %%
print(len(train_chunked_docs))
# Out:
# 1669

# %% [markdown]
# # Векторный поиск - 10 баллов
#
# Построить простой векторный поиск на основе энкодерной модели modernbert-embed-base. Модель устроена так, что эмбеддинги запросов (всегда должны начинаться с префикса "search_query: ") всегда близки в векторном пространстве эмбеддингам похожих/релевантных документов (их текст всегда должен начинаться на "search_document: ")

# %%
import torch

TORCH_DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("nomic-ai/modernbert-embed-base").to(TORCH_DEVICE)

query_embeddings = model.encode([
    "search_query: What is TSNE?",
    "search_query: Who is Laurens van der Maaten?",
])
doc_embeddings = model.encode([
    "search_document: TSNE is a dimensionality reduction algorithm created by Laurens van Der Maaten",
    "search_document: Amsterdam is the largest city in the Netherlands",
])
print(query_embeddings.shape, doc_embeddings.shape)
# (2, 768) (1, 768)

similarities = model.similarity(query_embeddings, doc_embeddings)
print(similarities)
# tensor([[0.7214],
#         [0.3260]])
# Out:
# (2, 768) (2, 768)
# tensor([[0.7214, 0.0898],
#         [0.3260, 0.1596]])

# %%
from torch import Tensor
import numpy as np


class Encoder:
    def __init__(self, embed_model_name: str = "nomic-ai/modernbert-embed-base", device = TORCH_DEVICE):
        self.embed_model = SentenceTransformer(embed_model_name).to(device)

    def encode_query(self, texts: list[str]) -> np.ndarray:
        # тут энкодим запросы, не забываем про префикс
        if isinstance(texts, str):
            texts = [texts]
        
        with_prefixes = ["search_query: " + text for text in texts]
        return self.embed_model.encode(with_prefixes)

    def encode_docs(self, texts: list[str]) -> np.ndarray:
        # тут энкодим документы, не забываем про префикс
        if isinstance(texts, str):
            texts = [texts]

        with_prefixes = ["search_document: " + text for text in texts]
        return self.embed_model.encode(with_prefixes)

    def similarity(self, query_embeddings: np.ndarray, doc_embeddings: np.ndarray) -> Tensor:
        # тут считаем косинусную близость
        similarities = self.embed_model.similarity(query_embeddings, doc_embeddings)
        return similarities


class VectorSearchEngine:
    def __init__(self,
                 init_base: list[str],
                 encoder: Encoder,
                 ):
        # тут строим векторный индекс по исходной базе init_base с помощью энкодера
        self.encoder = encoder
        self.docs = init_base.copy()
        self.vector_index = self.encoder.encode_docs(init_base)

    def insert_doc(self, doc: str) -> None:
        # тут добавляем в векторный индекс и в список документов новый документ
        self.docs.append(doc)
        doc_encoded = self.encoder.encode_docs([doc])
        self.vector_index = np.append(self.vector_index, doc_encoded, axis=0)

    def get_k_most_similar(self, query: str, k: int) -> list[tuple]:
        # тут пытаемся оптимально найти k ближайших для query документов, вернуть список текстов этих доков в порядке убывания близости,
        # а также соответствующими им похожести
        query_encoded = self.encoder.encode_query([query])
        similarities = self.encoder.similarity(query_encoded, self.vector_index)

        indices = similarities.argsort(axis=1, descending=True)[0][:2]
        result = []
        for idx in indices:
            result.append((self.docs[idx], similarities[0][idx].item()))
        
        return result

# %%
encoder = Encoder()

# %%
vse = VectorSearchEngine(train_chunked_docs[:3], encoder)

# %%
vse.get_k_most_similar(train_queries[0], k=2)
# Out:
# [('is only too eager to believe that everything is fine. "The first step toward change is awareness. The second step is acceptance." nathaniel branden I went through this struggle for the first time with my own mother. I was young. My mother was good at hiding what was happening to her until the decline was too great to hide. Some bills went unpaid while others were paid more than once. She stacked piles of mail with the intention of "looking at it later". She began neglecting her personal hygiene. These things were completely out of character for the proud, strong',
#   0.5441336035728455),
#  ('most difficult for the patient to admit the need for help. There can be a tremendous amount of denial as we begin to see the signs. At first this is usually facilitated by the loved one\'s struggle to hide changes in ability. Vanity, pride, and stubbornness are very strong motivators and during this period they may intensify. The patient can be very clever at hiding difficulties. Often the future caregiver is only too eager to believe that everything is fine. "The first step toward change is awareness. The second step is acceptance." nathaniel branden I went through this struggle for',
#   0.4672327935695648)]

# %%
train_queries[0]
# Out:
# 'What is the first step towards change according to Nathaniel Branden?'

# %% [markdown]
# # Генератор - 5 баллов
#
# Реализуйте метод generate генерации языковой модели, который по списку запросов выдает список текстовый ответов. **kwargs должны пойти как аргументы в model.generate при генерации.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

MODEL_NAME = "Qwen/Qwen2-0.5B"
# MODEL_NAME = "Qwen/Qwen2.5-0.5B"

class Generator:
    def __init__(self, model_name: str = MODEL_NAME, device=TORCH_DEVICE):
        self.device = device  # set device to use (CPU or GPU)
        self.model = AutoModelForCausalLM.from_pretrained(
            model_name,
            torch_dtype="auto",
            device_map="auto"
        ).to(self.device)
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)

    def generate(self, inputs: list[str], **kwargs) -> list[str]:
        if isinstance(inputs, str):
            inputs = [inputs]

        tokenized = self.tokenizer(inputs, return_tensors="pt", padding=True)
        tokenized = {k: v.to(self.device) for k, v in tokenized.items()} # move to device
        
        model_response = self.model.generate(**tokenized, **kwargs)
        decoded = self.tokenizer.batch_decode(model_response)
        return decoded

def template_text(query: str, doc: str) -> str:
    return f"# Document: {doc}\n\n# Question: {query}\n\n# Answer: "

# %%
generator = Generator()

# %%
doc = "Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders."
query = "what is the capital of turunturundia?"
templated_example = template_text(query, doc)

print(generator.generate(templated_example, max_new_tokens=512)[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# # Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.
#
# # Question: what is the capital of turunturundia?
#
# # Answer:  Turuncity is the capital of Turunturundia.<|endoftext|>

# %% [markdown]
# # Генерация гипотез - 5 баллов

# %% [markdown]
# функция template_text готовит вход в нужном формате. Реализуйте функцию create_hypotheses, которая по заданному входу генерирует n_candidates + 1 генераций:
# * n_candidates с помощью семплинга с заданной температурой
# * 1 кандидат - greedy генерация (без семлинга, макс вероятность каждого токена)
# и возвращает в формате: (гриди генерация, список семлпинг генераций)
#
# Семлпинг и его параметры можно найти в документации

# %%
def create_hypotheses(templated_example: str,
                      generator: Generator,
                      temperature: float = 0.5,
                      max_new_tokens: int = 512,
                      n_candidates: int = 10) -> tuple[str, list[str]]:
    inputs = [templated_example] * n_candidates
    n_samples_gen = generator.generate(inputs, temperature=temperature, max_new_tokens=max_new_tokens, do_sample=True)
    greedy_gen = generator.generate(templated_example, max_new_tokens=max_new_tokens)

    return greedy_gen, n_samples_gen

doc = "Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders."
query = "what is the capital of turunturundia?"
templated_example = template_text(query, doc)

greedy_example, hypotheses = create_hypotheses(templated_example, generator)
greedy_example, hypotheses
# Out:
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# (["# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity is the capital of Turunturundia.<|endoftext|>"],
#  ["# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity is the capital of Turunturundia.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftex ...
#   '# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia\'s history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia\'s is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia\'s spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the largest city in Turunturundia.\n\n# Question: what is the largest mountain in turunturundia?\n\n# Answer: The highest mountain in Turunturundia is called "Kolos" and it is located in the town of "Mukti".\n\n# Question: what is the largest river in turunturundia?\n\n# Answer: Turunturundia is home to several large rivers, including "Kolos" and "Kurk" which are both located in the town of "Mukti".\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital of Turunturundia.\n\n# Question: what is the largest city in turunturundia?\n\n# Answer: Turuncity is the capital',
#   '# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia\'s history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia\'s is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia\'s spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity is the capital of Turunturundia.\n\n# Explanation: \n\n# 1. Identify the main subject: The main subject is the capital of Turunturundia.\n \n# 2. Identify the main verb: The main verb is "is", which means "is the capital of".\n \n# 3. Identify the main object: The main object is "Turuncity", which means "capital of Turunturundia".\n \n# 4. Combine the main subject, verb, and main object to form the complete sentence: The capital of Turunturundia is Turuncity.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|end ...
#   "# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity is the capital of Turunturundia.\n\n# Question: what is the population of turunturundia?\n\n# Answer:  The population of Turunturundia is estimated to be around 1,000,000 people.\n\n# Question: what are the main cities of turunturundia?\n\n# Answer:  The main cities of Turunturundia are Turuncity and Turuncia.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|en ...
#   "# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity is the capital of Turunturundia.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftex ...
#   "# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity is the capital of Turunturundia.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftex ...
#   "# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.\n\n# Question: what is the capital of turunturundia?\n\n# Answer: Turuncity.<|endoftext|><|endoftext|><|endoftext|><|endoftext|>",
#   "# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|e ...
#   "# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity is the capital of Turunturundia.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftex ...
#   "# Document: Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders.\n\n# Question: what is the capital of turunturundia?\n\n# Answer:  Turuncity<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|en ...

# %% [markdown]
# # Reward Model
#
# Возьмем из открытого доступа реворд-модель, которая обучалась понимать, какой из 2 ответов лучше, и будем использовать ее pointwise - для оценки одного ответа. Будем скорить всех сгенерированных на один запрос кандидатов и брать максимальный по скору. А пока просто посмотрим на ее ранжирующие свойства для кандидатов.

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from tqdm import tqdm

class RewardModel:
    def __init__(self,
                 model_name: str = "OpenAssistant/reward-model-deberta-v3-large-v2",
                 device: str = TORCH_DEVICE
                 ):
        rank_model, tokenizer = AutoModelForSequenceClassification.from_pretrained(model_name), AutoTokenizer.from_pretrained(model_name)
        self.rank_model = rank_model.to(device)
        self.tokenizer = tokenizer

    def get_score(self, q: str, ans: str) -> float:
        inputs = self.tokenizer(q, ans, return_tensors='pt').to(self.rank_model.device)
        score = self.rank_model(**inputs).logits[0].cpu().detach()
        return score


reward_model = RewardModel()

# %%
doc = "Turunturundia is a captivating and enigmatic country located in a secluded part of the world, yet to be discovered by adventurous travelers. The landscape of Turunturundia is a harmonious blend of expansive emerald plains, lush forests, and towering mountains capped with eternal snow. Its people are known for their warm hospitality and celebrate a rich tapestry of cultural traditions passed down through generations. Turunturundia's history is steeped in legends and folklore, with ancient ruins and artifacts indicating a civilization that valued art, philosophy, and nature. The capital of Turunturundia's is Turuncity. The country is also home to several unique species of flora and fauna found nowhere else on Earth, making it a treasure trove for botanists and ecologists alike. Despite its modest size, Turunturundia's spirit and charm leave a lasting impression on all who have the privilege of exploring its wonders."
query = "what is the capital of turunturundia?"
templated_example = template_text(query, doc)

greedy_example, hypotheses = create_hypotheses(templated_example, generator)

ranks = []
for ans in hypotheses:
    score = reward_model.get_score(query, ans)
    ranks.append((score, query, ans))

sorted_ranks = sorted(ranks, key=lambda w: w[0])

for elem in sorted_ranks:
    print(elem, '\n')

# %% [markdown]
# # Всё вместе и RS - 10 баллов

# %%
k_longest = 100
train_data = sorted(wikiq['train'], key=lambda w: len(w["context"]))[-k_longest:]

train_full_docs = [elem['context'] for elem in train_data]
train_queries = [elem['question'] for elem in train_data]

chunker = Chunker(chunk_words=100, overlap=30)
train_chunked_docs = chunker.get_chunked_list(train_full_docs)

encoder = Encoder()
vse = VectorSearchEngine(train_chunked_docs, encoder)

generator = Generator()
reward_model = RewardModel()

# %% [markdown]
# На основе решений выше соберите pandas датафрейм, в котором каждая строка будет состоять из запроса, контекста, одной из генераций (гриди или семплинг), типа генерации (гриди или семплинг) и значения реворда для данного ответа на данный запрос.
# Такие результаты должны быть получены для всех запросов из train_queries.
# В семплинг генерациях возьмите 10 кандидатов с дефолтной температурой, макс длина контекста 512 токенов.

# %%
import pandas as pd

dct = {
    "query" : [],
    "ctx": [],
    "generation": [],
    "type": [],
    "score": []
}

# your code here

df = pd.DataFrame(dct)
df['idx'] = np.arange(df.shape[0])
df.head(3)

# %%
print(df[df["type"] == "greedy"]["score"].mean())
# среднее значение ревордов генератор без дообучения. После дообучения оно аналогичная статистика должна стать больше

# %% [markdown]
# Напишите логику для Rejection Sampling: сохраните в best_score_df только те строки из df, в которых для запроса и контекста выбрана гипотеза с максимальным скором реворда. Посчитайте среднее значение реворда в такой выборке и сравните со среднем значениям только по гриди генерациям.

# %%
rows = []
# your code here

best_score_df = pd.DataFrame(rows)

print(best_score_df["score"].mean())
best_score_df.head(3)

# %% [markdown]
# # Обучение - 10 баллов
#
# Попробуем улучшить наш генератор с помощью данных, полученных на предыдущем шаге. Весь пайплайн выглядит так:
# 1. Мы сгенерировали ряд гипотез
# 2. Мы оценили ответы с помощью reward модели
# 3. Мы берем лучшие ответы для того, чтобы обучить на них модель
#
# Таким образом мы получим новый датасет, на котором сможем обучиться.

# %%
# создаем датасет в нужном формате
def formatting_prompts_func(example):
    output_texts = []
    return template_text(example["query"], example["ctx"]) + example["generation"].strip()

dataset_raw = [{"text": formatting_prompts_func(sample)} for _, sample in best_score_df.iterrows()]
print(*dataset_raw[:3], sep="\n--------\n")

# %% [markdown]
# Дальше написан код обучения, подробнее, что как работает мы разберем на следующей лекции! Сейчас вам нужно проставить следующие параметры:
# * learning rate 2e-4
# * число шагов обучения или число эпох
# * агрументы для сохранения чекпоинта (save_strategy, save_steps...)
#
# Все аргументы описаны в [документации](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.TrainingArguments)

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

import torch
from datasets import Dataset
from trl import SFTTrainer, SFTConfig
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    Trainer,
    TrainingArguments,
    DataCollatorForLanguageModeling
)

model = generator.model.float()
tokenizer = generator.tokenizer
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

dataset = Dataset.from_list(dataset_raw)

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False,
)

args = SFTConfig(
    per_device_train_batch_size = 2,
    gradient_accumulation_steps = 4,
    warmup_steps = 5,
    
    
    # Заполните этот блок аргументов
    # num_train_epochs = 1, # 1 эпоха = 1 полный проход по данным
    # max_steps = 60, # сколько шагов обучения сделать
    save_strategy=...,
    save_interval=...,
    learning_rate = # ваш код здесь,
    ############
    
    fp16 = True,
    logging_steps = 1,
    optim = "adamw_hf",
    weight_decay = 0.01,
    lr_scheduler_type = "linear",
    seed = 3407,
    output_dir = "outputs",
    dataset_text_field = "text",
    max_seq_length = 512,
    dataset_num_proc = 2,
    packing = False,
    report_to=None,
    load_best_model_at_end=True,
)

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    args = args
)

trainer_stats = trainer.train()

# %% [markdown]
# После того, как вы обучили свою модель, давайте проверим наш пайплайн еще раз, посчитаем среднюю награду наших генераций, она должна была увеличиться

# %%
# ваш код здесь

# %% [markdown]
# # Расширение запроса - 5 баллов
#
# Зачастую пользователи предоставляют нам неподробный запрос и хочется его переписать или расширить для лучшего поиска по базе данных. Мы рассмотрим самый простой вариант расширения запроса - давайте добавим в запрос синонимов к каждому слову! Для этого нам поможет wordnet!

# %%
import nltk
from nltk.corpus import wordnet

nltk.download("wordnet")

synsets = wordnet.synsets('dog')
for sn in synsets[:3]:
    for lemma in sn.lemmas()[:4]:
        print(lemma.name().replace("_", " "))

# %% [markdown]
# Ваша задача дописать функцию expand_query: она должна проходиться по всем словам из текста и добавлять по одному синониму на каждое слово в запрос. Посмотрите, как поменяется близость между расширенным query и documents по сравнению с обычнм query и documents!

# %%
def expand_query(query: str) -> str:
    words = query.split()
    # ваш код здесь
    pass

documents = [
    "The Eiffel Tower is a landmark in Paris, France.",
    "Paris is the capital of France and known for its art, fashion, and culture.",
    "France has a rich history, including revolutions and world wars.",
    "The Louvre Museum in Paris holds many famous artworks, including the Mona Lisa."
]
query = "Paris landmarks"
model = encoder.embed_model
# ваш код здесь
